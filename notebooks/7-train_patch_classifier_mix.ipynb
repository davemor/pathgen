# %%
# generate the mixed data set
import os
import shutil

def copy_sample(src, dest, count):
    src_files = os.listdir(src)
    src_files = src_files[:count]
    for file_name in src_files:
        full_file_name = os.path.join(src, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy(full_file_name, dest)
            
copy_sample(experiment_root / "fake_patches" / "normal", experiment_root / "mixed_patches" / "normal", 17500)
copy_sample(experiment_root / "train_patches" / "normal", experiment_root / "mixed_patches" / "normal", 17500)
copy_sample(experiment_root / "fake_patches" / "tumor", experiment_root / "mixed_patches" / "tumor", 17500)
copy_sample(experiment_root / "train_patches" / "tumor", experiment_root / "mixed_patches" / "tumor", 17500)

# %%
from pathgen.utils.seeds import set_seed
from pathgen.utils.paths import project_root

experiment_name = "all"
experiment_root = project_root() / "experiments" / experiment_name

global_seed = 123
set_seed(global_seed)

# %%
import numpy as np
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torch
from torch import nn
import torch.nn.functional as F
from pytorch_lightning.metrics import Accuracy

def accuracy(logits, y):
    # pred = torch.log_softmax(logits, dim=1)
    # correct = pred.argmax(dim=1).eq(y).sum().item()
    correct = logits.argmax(dim=1).eq(y).sum().item()
    total = len(y)
    accu = correct / total
    return accu


class PatchClassifier(pl.LightningModule):
    def __init__(self, model, learning_rate=2e-4) -> None:
        super().__init__()
        self.model = model
        #self.accuracy = Accuracy()
        # self.accuracy = accuracy
        
        # log hyperparameters
        # self.save_hyperparameters()
        self.learning_rate = learning_rate
        self.test_pred = []
        self.test_y = []

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self.model(x)
        loss = F.nll_loss(logits, y)
        
        # training metrics
        acc = accuracy(logits, y)
        self.log('train_loss', loss, prog_bar=True, on_epoch=True, on_step=False)
        self.log('train_acc', acc, prog_bar=True, on_epoch=True, on_step=False)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self.model(x)
        loss = F.nll_loss(logits, y)
        
        # training metrics
        acc = accuracy(logits, y)
        self.log('val_loss', loss, prog_bar=False, on_epoch=True, on_step=False)
        self.log('val_acc', acc, prog_bar=True, on_epoch=True, on_step=False)
        return loss
    
    def test_step(self, batch, batch_idx):
        x, y = batch
        logits = self.model(x)
        loss = F.nll_loss(logits, y)
        
        # log the results so we can compute epoch wide metrics
        pred = logits.argmax(dim=1)
        pred_list = pred.cpu().numpy().tolist()
        #print(pred_list)
        y_list = y.cpu().numpy().tolist()
        #print(y_list)
        self.test_pred.append(pred_list)
        self.test_y.append(y_list)
        
        # training metrics
        acc = accuracy(logits, y)
        self.log('test_loss', loss, prog_bar=True)
        self.log('test_acc', acc, prog_bar=True)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.SGD(self.model.parameters(), 
                                    lr=0.001, 
                                    momentum=0.9, 
                                    weight_decay=0.0005)
        scheduler = {
            'scheduler': torch.optim.lr_scheduler.StepLR(optimizer, step_size=2000, gamma=0.5),
            'interval': 'step' 
        }
        return [optimizer], [scheduler]
    
    #def configure_optimizers(self):
     #  optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
        #return optimizer

# %%
in_channels = 3
number_of_filters = 32
kernel_size = 3
stride = 1

def conv2d_output_size(w, h, in_channels, number_of_filters, kernel_size, stride, padding=0):
    out_width = int((w - kernel_size + 2*padding)/stride + 1)
    out_height = int((h - kernel_size + 2*padding)/stride + 1)
    out_channels = number_of_filters
    return out_width, out_height, out_channels

w2, h2, d2 = conv2d_output_size(64, 64, 3, 32, 3, 1, 0)
w3, h3, d3 = conv2d_output_size(w2, h2, d2, 32, 3, 1, 0)
w4, h4, d4 = conv2d_output_size(w3, h3, d3, 64, 3, 1, 0)
wo, ho, do = conv2d_output_size(w4, h4, d4, 64, 3, 1, 0)
print(wo * ho * do)
print(wo, ho, do)
# Out:
# 200704
# 56 56 64

# %%
import torch
from torch import nn
import torch.nn.functional as F

class Backbone(nn.Module):
    def __init__(self, input_shape, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 32, 3, 1)
        self.conv3 = nn.Conv2d(32, 64, 3, 1)
        self.conv4 = nn.Conv2d(64, 64, 3, 1)

        self.pool1 = torch.nn.MaxPool2d(2)
        self.pool2 = torch.nn.MaxPool2d(2)
        
        n_sizes = self._get_conv_output(input_shape)
        print(n_sizes)
        
        self.fc1 = nn.Linear(n_sizes, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, num_classes)

    # returns the size of the output tensor going into Linear layer from the conv block.
    def _get_conv_output(self, shape):
        batch_size = 1
        input = torch.autograd.Variable(torch.rand(batch_size, *shape))

        output_feat = self._forward_features(input) 
        n_size = output_feat.data.view(batch_size, -1).size(1)
        return n_size
        
    # returns the feature tensor from the conv block
    def _forward_features(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = self.pool2(F.relu(self.conv4(x)))
        return x
    
    # will be used during inference
    def forward(self, x):
       x = self._forward_features(x)
       x = x.view(x.size(0), -1)
       x = F.relu(self.fc1(x))
       x = F.relu(self.fc2(x))
       x = F.log_softmax(self.fc3(x), dim=1)
       
       return x

# %%
# %%time

from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning import loggers as pl_loggers
import torchvision.transforms as transforms

# prepare our data
batch_size = 128
max_epochs = 50

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_set = ImageFolder(experiment_root / 'mixed_patches', transform=transform)  # 70,000 samples (35,000 per class) - fake
valid_set = ImageFolder(experiment_root / 'valid_patches', transform=transform)  # 30,000 samples (15,000 per class) - non-fake

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, worker_init_fn=np.random.seed(global_seed), num_workers=32)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True, worker_init_fn=np.random.seed(global_seed), num_workers=32)

# configure logging and checkpoints
checkpoint_callback = ModelCheckpoint(
    monitor="val_acc",
    dirpath=experiment_root / "patch_model",
    filename=f"checkpoint.ckpt",
    save_top_k=1,
    mode="max",
)

early_stop_callback = EarlyStopping(
    monitor='val_acc',
    min_delta=0.00,
    patience=5,
    verbose=False,
    mode='max'
)

csv_logger = pl_loggers.CSVLogger(experiment_root / 'logs', name='patch_classifier_mixed', version=0)

# train our model
model = Backbone((3, 64, 64), 2)
classifier = PatchClassifier(model)
trainer = pl.Trainer(callbacks=[checkpoint_callback, early_stop_callback], log_every_n_steps=1, gpus=1, max_epochs=max_epochs, logger=csv_logger, auto_select_gpus=False)
trainer.fit(classifier, train_dataloader=train_loader, val_dataloaders=valid_loader)
# Out:
# /home/ubuntu/anaconda3/envs/pathgen/lib/python3.6/site-packages/pytorch_lightning/utilities/distributed.py:51: UserWarning: Checkpoint directory /home/ubuntu/pathgen/experiments/all/patch_model exists and is not empty.
#   warnings.warn(*args, **kwargs)
# 10816
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
#
#   | Name  | Type     | Params
# -----------------------------------
# 0 | model | Backbone | 5.7 M
# -----------------------------------
# 5.7 M     Trainable params
# 0         Non-trainable params
# 5.7 M     Total params
# 22.679    Total estimated model params size (MB)
# Validation sanity check:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/ubuntu/anaconda3/envs/pathgen/lib/python3.6/site-packages/pytorch_lightning/utilities/distributed.py:51: UserWarning: Your val_dataloader has `shuffle=True`, it is best practice to turn this off for validation and test dataloaders.
#   warnings.warn(*args, **kwargs)
# Epoch 0:  70%|███████   | 548/782 [00:12<00:05, 44.21it/s, loss=0.691, v_num=0, val_acc=0.488]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Epoch 0:  71%|███████   | 555/782 [00:14<00:05, 38.54it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  73%|███████▎  | 570/782 [00:14<00:05, 39.30it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  75%|███████▍  | 585/782 [00:14<00:04, 39.60it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  77%|███████▋  | 601/782 [00:14<00:04, 40.40it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  79%|███████▉  | 617/782 [00:15<00:04, 40.51it/s, loss=0.691, v_num=0, val_acc=0.488]
# Validating:  30%|███       | 71/235 [00:02<00:03, 42.08it/s]
# Epoch 0:  81%|████████  | 633/782 [00:15<00:03, 41.11it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  83%|████████▎ | 649/782 [00:15<00:03, 40.95it/s, loss=0.691, v_num=0, val_acc=0.488]
# Validating:  45%|████▍     | 105/235 [00:03<00:02, 46.29it/s]
# Epoch 0:  85%|████████▌ | 665/782 [00:16<00:02, 41.48it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  87%|████████▋ | 681/782 [00:16<00:02, 41.52it/s, loss=0.691, v_num=0, val_acc=0.488]
# Validating:  57%|█████▋    | 135/235 [00:04<00:02, 47.53it/s]
# Epoch 0:  89%|████████▉ | 697/782 [00:16<00:02, 42.05it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  91%|█████████ | 713/782 [00:16<00:01, 42.21it/s, loss=0.691, v_num=0, val_acc=0.488]
# Validating:  71%|███████   | 167/235 [00:04<00:01, 54.34it/s]
# Epoch 0:  93%|█████████▎| 729/782 [00:17<00:01, 42.84it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  95%|█████████▌| 745/782 [00:17<00:00, 43.00it/s, loss=0.691, v_num=0, val_acc=0.488]
# Epoch 0:  97%|█████████▋| 761/782 [00:17<00:00, 43.63it/s, loss=0.691, v_num=0, val_acc=0.488]
# Validating:  93%|█████████▎| 218/235 [00:05<00:00, 82.60it/s]
# Epoch 0: 100%|██████████| 782/782 [00:17<00:00, 43.68it/s, loss=0.691, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  70%|██████▉   | 547/782 [00:12<00:05, 45.22it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Validating:   0%|          | 1/235 [00:01<07:13,  1.85s/it]
# Epoch 1:  72%|███████▏  | 560/782 [00:14<00:05, 39.04it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  74%|███████▍  | 577/782 [00:14<00:05, 39.94it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Validating:  13%|█▎        | 30/235 [00:02<00:07, 28.11it/s]
# Epoch 1:  76%|███████▌  | 594/782 [00:14<00:04, 39.70it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  78%|███████▊  | 611/782 [00:15<00:04, 40.56it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Validating:  29%|██▉       | 68/235 [00:02<00:03, 49.33it/s]
# Epoch 1:  80%|████████  | 628/782 [00:15<00:03, 40.29it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  82%|████████▏ | 645/782 [00:15<00:03, 41.11it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  85%|████████▍ | 662/782 [00:16<00:02, 41.01it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Validating:  51%|█████▏    | 121/235 [00:03<00:02, 56.33it/s]
# Epoch 1:  87%|████████▋ | 679/782 [00:16<00:02, 41.28it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  89%|████████▉ | 696/782 [00:16<00:02, 41.48it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Validating:  65%|██████▌   | 153/235 [00:04<00:01, 57.23it/s]
# Epoch 1:  91%|█████████ | 713/782 [00:17<00:01, 41.73it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  93%|█████████▎| 730/782 [00:17<00:01, 42.30it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Validating:  79%|███████▉  | 186/235 [00:05<00:00, 71.95it/s]
# Epoch 1:  96%|█████████▌| 747/782 [00:17<00:00, 42.43it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1:  98%|█████████▊| 765/782 [00:17<00:00, 43.20it/s, loss=0.678, v_num=0, val_acc=0.500, train_loss=0.692, train_acc=0.544]
# Epoch 1: 100%|██████████| 782/782 [00:18<00:00, 43.11it/s, loss=0.678, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  70%|██████▉   | 547/782 [00:12<00:05, 44.71it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Validating:   0%|          | 1/235 [00:01<07:22,  1.89s/it]
# Epoch 2:  71%|███████▏  | 558/782 [00:14<00:05, 38.84it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  74%|███████▎  | 576/782 [00:14<00:05, 39.79it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Validating:  14%|█▍        | 33/235 [00:02<00:07, 26.12it/s]
# Epoch 2:  76%|███████▌  | 594/782 [00:14<00:04, 39.64it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  78%|███████▊  | 612/782 [00:15<00:04, 40.54it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  81%|████████  | 630/782 [00:15<00:03, 40.29it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Validating:  36%|███▌      | 85/235 [00:03<00:03, 49.16it/s]
# Epoch 2:  83%|████████▎ | 648/782 [00:16<00:03, 40.30it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  85%|████████▌ | 666/782 [00:16<00:02, 41.11it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Validating:  53%|█████▎    | 125/235 [00:03<00:01, 62.41it/s]
# Epoch 2:  87%|████████▋ | 684/782 [00:16<00:02, 41.20it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  90%|████████▉ | 702/782 [00:16<00:01, 41.98it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  92%|█████████▏| 720/782 [00:17<00:01, 42.12it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Validating:  74%|███████▎  | 173/235 [00:04<00:01, 56.77it/s]
# Epoch 2:  94%|█████████▍| 738/782 [00:17<00:01, 42.89it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  97%|█████████▋| 756/782 [00:17<00:00, 43.10it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2:  99%|█████████▉| 774/782 [00:17<00:00, 43.86it/s, loss=0.562, v_num=0, val_acc=0.724, train_loss=0.687, train_acc=0.619]
# Epoch 2: 100%|██████████| 782/782 [00:18<00:00, 43.44it/s, loss=0.562, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  70%|██████▉   | 547/782 [00:12<00:05, 45.04it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Validating:   0%|          | 1/235 [00:01<07:18,  1.87s/it]
# Epoch 3:  71%|███████▏  | 558/782 [00:14<00:05, 38.96it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  74%|███████▎  | 576/782 [00:14<00:05, 39.87it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Validating:  13%|█▎        | 30/235 [00:02<00:07, 27.57it/s]
# Epoch 3:  76%|███████▌  | 594/782 [00:14<00:04, 39.67it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  78%|███████▊  | 612/782 [00:15<00:04, 40.59it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Validating:  28%|██▊       | 65/235 [00:02<00:03, 50.36it/s]
# Epoch 3:  81%|████████  | 630/782 [00:15<00:03, 40.32it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  83%|████████▎ | 648/782 [00:15<00:03, 40.90it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Validating:  43%|████▎     | 102/235 [00:03<00:02, 53.67it/s]
# Epoch 3:  85%|████████▌ | 666/782 [00:16<00:02, 41.20it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  87%|████████▋ | 684/782 [00:16<00:02, 41.41it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Validating:  59%|█████▊    | 138/235 [00:04<00:01, 51.90it/s]
# Epoch 3:  90%|████████▉ | 702/782 [00:16<00:01, 41.87it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Validating:  69%|██████▊   | 161/235 [00:04<00:01, 66.20it/s]
# Epoch 3:  92%|█████████▏| 720/782 [00:17<00:01, 41.89it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  94%|█████████▍| 738/782 [00:17<00:01, 42.69it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  97%|█████████▋| 756/782 [00:17<00:00, 42.71it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3:  99%|█████████▉| 774/782 [00:17<00:00, 43.40it/s, loss=0.488, v_num=0, val_acc=0.769, train_loss=0.604, train_acc=0.712]
# Epoch 3: 100%|██████████| 782/782 [00:18<00:00, 43.00it/s, loss=0.488, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  70%|██████▉   | 547/782 [00:12<00:05, 44.05it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Validating:   0%|          | 1/235 [00:02<08:11,  2.10s/it]
# Epoch 4:  71%|███████▏  | 558/782 [00:14<00:05, 37.34it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  74%|███████▎  | 576/782 [00:15<00:05, 38.25it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  76%|███████▌  | 594/782 [00:15<00:04, 38.08it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Validating:  20%|██        | 47/235 [00:03<00:06, 29.47it/s]
# Epoch 4:  78%|███████▊  | 612/782 [00:15<00:04, 38.89it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  81%|████████  | 630/782 [00:16<00:03, 38.82it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Validating:  37%|███▋      | 86/235 [00:03<00:03, 47.22it/s]
# Epoch 4:  83%|████████▎ | 648/782 [00:16<00:03, 38.60it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  85%|████████▌ | 666/782 [00:16<00:02, 39.36it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  87%|████████▋ | 684/782 [00:17<00:02, 39.28it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Validating:  58%|█████▊    | 137/235 [00:04<00:02, 43.65it/s]
# Epoch 4:  90%|████████▉ | 702/782 [00:17<00:01, 40.05it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  92%|█████████▏| 720/782 [00:18<00:01, 39.96it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  94%|█████████▍| 738/782 [00:18<00:01, 40.72it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Validating:  82%|████████▏ | 192/235 [00:05<00:00, 66.89it/s]
# Epoch 4:  97%|█████████▋| 756/782 [00:18<00:00, 40.88it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4:  99%|█████████▉| 774/782 [00:18<00:00, 41.61it/s, loss=0.446, v_num=0, val_acc=0.799, train_loss=0.514, train_acc=0.754]
# Epoch 4: 100%|██████████| 782/782 [00:18<00:00, 41.17it/s, loss=0.446, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  70%|██████▉   | 547/782 [00:12<00:05, 44.45it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Validating:   0%|          | 1/235 [00:02<07:48,  2.00s/it]
# Validating:   1%|          | 2/235 [00:02<03:37,  1.07it/s]
# Validating:   3%|▎         | 6/235 [00:02<00:54,  4.19it/s]
# Epoch 5:  71%|███████▏  | 558/782 [00:15<00:06, 37.15it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  74%|███████▎  | 576/782 [00:15<00:05, 38.09it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating:  16%|█▌        | 38/235 [00:02<00:06, 31.91it/s]
# Epoch 5:  76%|███████▌  | 594/782 [00:15<00:04, 38.35it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  78%|███████▊  | 612/782 [00:15<00:04, 39.16it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  81%|████████  | 630/782 [00:16<00:03, 39.26it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating:  37%|███▋      | 87/235 [00:03<00:02, 58.50it/s]
# Epoch 5:  83%|████████▎ | 648/782 [00:16<00:03, 39.59it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  85%|████████▌ | 666/782 [00:16<00:02, 39.79it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating:  51%|█████     | 120/235 [00:04<00:02, 55.82it/s]
# Epoch 5:  87%|████████▋ | 684/782 [00:17<00:02, 39.93it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating:  59%|█████▊    | 138/235 [00:04<00:01, 49.88it/s]
# Epoch 5:  90%|████████▉ | 702/782 [00:17<00:01, 40.65it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating:  69%|██████▉   | 162/235 [00:05<00:01, 63.38it/s]
# Epoch 5:  92%|█████████▏| 720/782 [00:17<00:01, 40.79it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  94%|█████████▍| 738/782 [00:17<00:01, 41.54it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Validating:  84%|████████▍ | 197/235 [00:05<00:00, 69.53it/s]
# Epoch 5:  97%|█████████▋| 756/782 [00:18<00:00, 41.74it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5:  99%|█████████▉| 774/782 [00:18<00:00, 42.31it/s, loss=0.405, v_num=0, val_acc=0.803, train_loss=0.466, train_acc=0.786]
# Epoch 5: 100%|██████████| 782/782 [00:18<00:00, 42.02it/s, loss=0.405, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  70%|██████▉   | 547/782 [00:12<00:05, 44.35it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Epoch 6:  71%|███████▏  | 558/782 [00:14<00:05, 38.43it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  74%|███████▎  | 576/782 [00:14<00:05, 39.35it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating:  14%|█▎        | 32/235 [00:02<00:08, 23.50it/s]
# Epoch 6:  76%|███████▌  | 594/782 [00:15<00:04, 39.21it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  78%|███████▊  | 612/782 [00:15<00:04, 40.04it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating:  28%|██▊       | 65/235 [00:02<00:04, 40.98it/s]
# Epoch 6:  81%|████████  | 630/782 [00:15<00:03, 40.03it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating:  38%|███▊      | 90/235 [00:03<00:02, 51.71it/s]
# Epoch 6:  83%|████████▎ | 648/782 [00:16<00:03, 40.38it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  85%|████████▌ | 666/782 [00:16<00:02, 40.60it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating:  52%|█████▏    | 122/235 [00:03<00:02, 54.96it/s]
# Epoch 6:  87%|████████▋ | 684/782 [00:16<00:02, 40.66it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  90%|████████▉ | 702/782 [00:16<00:01, 41.45it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating:  66%|██████▋   | 156/235 [00:04<00:01, 65.73it/s]
# Epoch 6:  92%|█████████▏| 720/782 [00:17<00:01, 41.61it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  94%|█████████▍| 738/782 [00:17<00:01, 42.37it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Validating:  81%|████████▏ | 191/235 [00:04<00:00, 78.43it/s]
# Epoch 6:  97%|█████████▋| 756/782 [00:17<00:00, 42.56it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6:  99%|█████████▉| 774/782 [00:17<00:00, 43.32it/s, loss=0.388, v_num=0, val_acc=0.805, train_loss=0.432, train_acc=0.806]
# Epoch 6: 100%|██████████| 782/782 [00:18<00:00, 42.89it/s, loss=0.388, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  70%|██████▉   | 547/782 [00:12<00:05, 44.82it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Epoch 7:  71%|███████▏  | 558/782 [00:14<00:05, 38.71it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  74%|███████▎  | 576/782 [00:14<00:05, 39.65it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  76%|███████▌  | 594/782 [00:14<00:04, 39.90it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  78%|███████▊  | 612/782 [00:14<00:04, 40.81it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Validating:  28%|██▊       | 65/235 [00:02<00:04, 36.61it/s]
# Epoch 7:  81%|████████  | 630/782 [00:15<00:03, 40.64it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  83%|████████▎ | 648/782 [00:15<00:03, 40.80it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  85%|████████▌ | 666/782 [00:15<00:02, 41.65it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Validating:  51%|█████     | 119/235 [00:03<00:01, 63.06it/s]
# Epoch 7:  87%|████████▋ | 684/782 [00:16<00:02, 41.69it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  90%|████████▉ | 702/782 [00:16<00:01, 42.48it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Validating:  69%|██████▊   | 161/235 [00:04<00:01, 68.32it/s]
# Epoch 7:  92%|█████████▏| 720/782 [00:16<00:01, 42.62it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  94%|█████████▍| 738/782 [00:17<00:01, 43.40it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  97%|█████████▋| 756/782 [00:17<00:00, 43.58it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7:  99%|█████████▉| 774/782 [00:17<00:00, 43.90it/s, loss=0.346, v_num=0, val_acc=0.796, train_loss=0.400, train_acc=0.824]
# Epoch 7: 100%|██████████| 782/782 [00:17<00:00, 43.79it/s, loss=0.346, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Epoch 8:  70%|██████▉   | 547/782 [00:12<00:05, 44.18it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Epoch 8:  71%|███████▏  | 558/782 [00:14<00:05, 38.32it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:   5%|▌         | 12/235 [00:02<00:28,  7.85it/s]
# Epoch 8:  74%|███████▎  | 576/782 [00:14<00:05, 39.22it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  16%|█▌        | 37/235 [00:02<00:08, 24.45it/s]
# Epoch 8:  76%|███████▌  | 594/782 [00:15<00:04, 39.42it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Epoch 8:  78%|███████▊  | 612/782 [00:15<00:04, 40.32it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Epoch 8:  81%|████████  | 630/782 [00:15<00:03, 40.11it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  35%|███▌      | 83/235 [00:03<00:03, 42.21it/s]
# Epoch 8:  83%|████████▎ | 648/782 [00:15<00:03, 40.84it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Epoch 8:  85%|████████▌ | 666/782 [00:16<00:02, 40.70it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  51%|█████     | 119/235 [00:03<00:02, 44.10it/s]
# Epoch 8:  87%|████████▋ | 684/782 [00:16<00:02, 41.33it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  59%|█████▊    | 138/235 [00:04<00:01, 57.64it/s]
# Epoch 8:  90%|████████▉ | 702/782 [00:16<00:01, 41.48it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  67%|██████▋   | 158/235 [00:04<00:01, 59.60it/s]
# Epoch 8:  92%|█████████▏| 720/782 [00:17<00:01, 41.76it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  74%|███████▍  | 175/235 [00:04<00:01, 54.91it/s]
# Epoch 8:  94%|█████████▍| 738/782 [00:17<00:01, 42.37it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Epoch 8:  97%|█████████▋| 756/782 [00:17<00:00, 42.55it/s, loss=0.314, v_num=0, val_acc=0.794, train_loss=0.358, train_acc=0.848]
# Validating:  91%|█████████ | 214/235 [00:05<00:00, 71.33it/s]
# Epoch 8: 100%|██████████| 782/782 [00:18<00:00, 42.86it/s, loss=0.314, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  70%|██████▉   | 547/782 [00:12<00:05, 45.37it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Validating:   0%|          | 1/235 [00:01<07:35,  1.95s/it]
# Epoch 9:  71%|███████▏  | 558/782 [00:14<00:05, 39.17it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  74%|███████▎  | 576/782 [00:14<00:05, 40.07it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Validating:  14%|█▍        | 33/235 [00:02<00:08, 24.65it/s]
# Epoch 9:  76%|███████▌  | 594/782 [00:14<00:04, 40.16it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  78%|███████▊  | 612/782 [00:14<00:04, 41.06it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Validating:  29%|██▊       | 67/235 [00:02<00:04, 40.77it/s]
# Epoch 9:  81%|████████  | 630/782 [00:15<00:03, 40.82it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  83%|████████▎ | 648/782 [00:15<00:03, 41.49it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Validating:  43%|████▎     | 102/235 [00:03<00:02, 61.48it/s]
# Epoch 9:  85%|████████▌ | 666/782 [00:15<00:02, 41.73it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  87%|████████▋ | 684/782 [00:16<00:02, 42.00it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Validating:  58%|█████▊    | 137/235 [00:04<00:01, 55.13it/s]
# Epoch 9:  90%|████████▉ | 702/782 [00:16<00:01, 42.66it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Validating:  69%|██████▊   | 161/235 [00:04<00:01, 70.19it/s]
# Epoch 9:  92%|█████████▏| 720/782 [00:16<00:01, 42.43it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  94%|█████████▍| 738/782 [00:17<00:01, 43.20it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  97%|█████████▋| 756/782 [00:17<00:00, 43.34it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9:  99%|█████████▉| 774/782 [00:17<00:00, 44.08it/s, loss=0.332, v_num=0, val_acc=0.787, train_loss=0.341, train_acc=0.857]
# Epoch 9: 100%|██████████| 782/782 [00:17<00:00, 43.60it/s, loss=0.332, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  70%|██████▉   | 547/782 [00:12<00:05, 43.37it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/235 [00:00<?, ?it/s]
# Epoch 10:  71%|███████▏  | 558/782 [00:14<00:05, 37.89it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Validating:   5%|▌         | 12/235 [00:02<00:27,  8.11it/s]
# Epoch 10:  74%|███████▎  | 576/782 [00:14<00:05, 38.80it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  76%|███████▌  | 594/782 [00:15<00:04, 37.85it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  78%|███████▊  | 612/782 [00:16<00:04, 38.08it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Validating:  28%|██▊       | 66/235 [00:03<00:05, 30.25it/s]
# Epoch 10:  81%|████████  | 630/782 [00:16<00:03, 38.86it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  83%|████████▎ | 648/782 [00:16<00:03, 39.17it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  85%|████████▌ | 666/782 [00:16<00:02, 39.96it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Validating:  51%|█████     | 119/235 [00:03<00:01, 63.87it/s]
# Epoch 10:  87%|████████▋ | 684/782 [00:17<00:02, 39.44it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  90%|████████▉ | 702/782 [00:17<00:01, 40.22it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Validating:  66%|██████▋   | 156/235 [00:04<00:01, 57.83it/s]
# Epoch 10:  92%|█████████▏| 720/782 [00:17<00:01, 40.86it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  94%|█████████▍| 738/782 [00:17<00:01, 41.36it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Epoch 10:  97%|█████████▋| 756/782 [00:17<00:00, 42.12it/s, loss=0.321, v_num=0, val_acc=0.790, train_loss=0.336, train_acc=0.860]
# Validating:  90%|█████████ | 212/235 [00:05<00:00, 93.71it/s]
# Epoch 10: 100%|██████████| 782/782 [00:18<00:00, 42.29it/s, loss=0.321, v_num=0, val_acc=0.788, train_loss=0.325, train_acc=0.864]
# Epoch 10: 100%|██████████| 782/782 [00:18<00:00, 42.26it/s, loss=0.321, v_num=0, val_acc=0.788, train_loss=0.325, train_acc=0.864]
# CPU times: user 1min 48s, sys: 1min 7s, total: 2min 55s
# Wall time: 3min 28s
# 1

# %%
# test
test_set = ImageFolder(experiment_root / 'test_patches', transform=transform)
test_loader = DataLoader(test_set, batch_size=batch_size, worker_init_fn=np.random.seed(global_seed), num_workers=32)
trainer.test(test_dataloaders=test_loader)
# Out:
# Testing: 100%|██████████| 235/235 [00:05<00:00, 41.74it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.7365666627883911, 'test_loss': 0.5835191607475281}
# --------------------------------------------------------------------------------
# [{'test_loss': 0.5835191607475281, 'test_acc': 0.7365666627883911}]

# %%
import pandas as pd

log_df = pd.read_csv(experiment_root / 'logs/patch_classifier_mixed/version_0/metrics.csv')
train_log = log_df[['train_loss', 'train_acc', 'epoch']].dropna()
valid_log = log_df[['val_loss', 'val_acc', 'epoch']].dropna()
test_log = log_df[['test_loss', 'test_acc', 'epoch']].dropna()

# %%
valid_log
# Out:
#     val_loss   val_acc  epoch
# 1   0.691115  0.499933      0
# 3   0.671461  0.724300      1
# 5   0.513421  0.769400      2
# 7   0.468533  0.799300      3
# 9   0.453669  0.802867      4
# 11  0.452507  0.804833      5
# 13  0.455484  0.796167      6
# 15  0.471073  0.794033      7
# 17  0.466053  0.786667      8
# 19  0.483979  0.789633      9
# 21  0.475505  0.788433     10

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure()
plt.plot(train_log.epoch, train_log.train_loss, label="training loss")
plt.plot(valid_log.epoch, valid_log.val_loss, label="validation loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Patch Classifier Mixed Data Loss")
plt.legend()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure()
plt.plot(train_log.epoch, train_log.train_acc, label="training accuracy")
plt.plot(valid_log.epoch, valid_log.val_acc, label="validation accuracy")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("Patch Classifier Mixed Data Training Accuracy")
plt.legend()

# %%
len(classifier.test_pred), len(classifier.test_y)
expected = [x for xs in classifier.test_y for x in xs]
predicted = [x for xs in classifier.test_pred for x in xs]

# %%
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt

print(metrics.classification_report(expected, predicted, labels=[0, 1], target_names=['normal', 'tumor']))

cm = metrics.confusion_matrix(expected, predicted)

ax = plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt='g', cmap='Blues');

# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels'); 
ax.set_title('Patch Classifier Mixed Data Confusion Matrix'); 
ax.xaxis.set_ticklabels(['normal', 'tumor']); ax.yaxis.set_ticklabels(['normal', 'tumor']);
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.68      0.89      0.77     15000
#        tumor       0.85      0.58      0.69     15000
#
#     accuracy                           0.74     30000
#    macro avg       0.76      0.74      0.73     30000
# weighted avg       0.76      0.74      0.73     30000
